# %%
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
# %%writefile Binstar_h.pxd
#
#
#
#
#
#
#
#
#
#
# #the libraries needed:
#
# # distutils: language = c++
# from libcpp.string cimport string
# from libcpp.vector cimport vector
# from libcpp cimport bool
# #from libcpp cimport tWrap
# from libcpp.complex cimport complex
# from libc.float cimport float
# from libc.stdint cimport uint_fast32_t, uint_fast64_t
#
#
#
# #Importing the libraries:
#
#
# cdef extern from "<iostream>" namespace "std":
#     cdef cppclass istringstream[T]:
#         pass
#
#     cdef cppclass basic_istream[T]:
#         pass
#
#     cdef cppclass basic_ostream[T]:
#         pass
#
#     ctypedef basic_istream[char] istream
#
#     ctypedef basic_ostream[char] ostream
#
#     ctypedef istringstream[char] istringstream
#
#
#
# cdef extern from "<iostream>" namespace "std::ios_base":
#     cdef cppclass open_mode:
#         pass
#     cdef open_mode binary
#
#
# # you can define other constants as needed
# cdef extern from "<fstream>" namespace "std":
#     cdef cppclass ofstream(ostream):
#         # constructors
#         ofstream(const char*) except +
#         ofstream(const char*, open_mode) except+
#
# cdef extern from "<fstream>" namespace "std":
#     cdef cppclass ifstream(ostream):
#         # constructors
#         ifstream(const char*) except +
#         ifstream(const char*, open_mode) except+
#
#
#
# cdef extern from "<random>" namespace "std" nogil:
#     cdef cppclass random_device:
#         ctypedef uint_fast32_t result_type
#         random_device() except +
#         result_type operator()() except +
#
#
#
#
#
#
# #calling the cpp source files:
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/binstar/binstar.cpp":
# #     pass
#
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/general/IO.cpp":
# #     pass
#
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/general/utils/utilities.cpp":
# #     pass
#
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/star/star.cpp":
# #     pass
#
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/binstar/Processes.cpp":
# #    pass
#
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/binstar/BinaryProperty.cpp":
# #    pass
#
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/star/property.cpp":
# #    pass
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/src/general/utils/sevnlog.cpp":
# #    pass
#
#
#
#
#
#
# #calling classes or other dependencies that we need:
#
# cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/general/IO.h" :
#      cdef cppclass IO:
#         IO() except +
#         IO(int argc, char **argv) except +
#
#
# #cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/general/utils/utilities.h" namespace "utilities":
# #    pass
#
#
#
#
#
# cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/star/star.h":
#      cdef cppclass Star:
#         Star() except +
#         Star(IO *_io, vector[string] &params, size_t &_ID, bool pureHE=false, unsigned long _rseed=0) except +
#
#
#
#
#
#
#
# cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/binstar/Processes.h":
#     cdef cppclass Process:
#         Process() except +
#
#
#
# cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/binstar/BinaryProperty.h":
#     cdef cppclass BinaryProperty:
#         BinaryProperty() except +
#
# cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/star/property.h":
#     cdef cppclass Property:
#         Property() except +
#
#
# cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/general/utils/sevnlog.h" namespace "sevnstd":
#     cdef cppclass SevnLogging:
#         SevnLogging() except +
#
#
#
#
# cdef extern from "/Users/melikakeshavarz/Desktop/sevndevel/include/binstar/binstar.h":
#     cdef cppclass Binstar:
#         Binstar() except +
#         Binstar(IO *_io, vector[string] &params, size_t &_ID, unsigned long _rseed=0) except +
#
#
#
#
#         #public:
#
#     #MEMBERS:
#         ctypedef bool bse_evolution
#         ctypedef unsigned int sn_explosion
#         bool broken
#         bool onesurvived  # true if just one star survived else either both stars are present or no stars are present
#         bool empty
#         bool break_at_remnant  # if true stop the evolution when both stars are remnant
#         bool break_at_broken # if true stop the evolution when the binary breaks
#         bool repeatstep  #!Control if it is needed to repeat a step of the binary evolution. It is mostly used in BTimestep::evolve
#         bool mix # If true the binary is mixing
#         bool comenv # If true the binary is doing a  ce
#         bool is_swallowed[2] # Array of bool corresponding to the ID of stars in binary. If true, the star has been swallowed
#         double last_Timestep # it stores the last value of the Timestep used in the evolution
#         bool print_all_steps  #  If true print in output all the steps.
#         bool print_per_phase  # If true print in output in each phase change
#         bool print_only_end # If true do not print intermediate steps
#         bool print_events # If true print all the events
#         bool print_rlo # If true print all the steps during a rlo
#         bool disable_e_check # If true, the e_check in adpative timestep is disabled
#         bool disable_a_check # If true, the a_check in adpative timestep is disabled
#         bool disable_DM_check # If true, the DM_check (from binary evolution) in adpative timestep is disabled
#         bool disable_OmegaRem_NS_check # If true, the OmegaRem_NS_check (from binary evolution) in adpative timestep is disabled
#         bool disable_stellar_rotation_check # If true, the OmegaSpin (from binary evolution) in adpative timestep is disabled
#         bool force_tiny_dt # If true, it forces the next Binary time step to be equal to utilities::TINY
#
#         #Other variables
#         double CE_E_tomatch  # Envelope binding energy of the system after coalesce during a CE
#
#         #Guard
#         bool evolution_step_completed
#
#
#
#         #Methods:
#         inline double getp(const size_t &id)
#         inline double getp_0(const size_t &id)
#         inline string get_name() #this was std::string get_name()
#         inline size_t get_ID()
#         inline Star *getstar(const size_t &id)
#         inline Process *getprocess(const size_t &id)
#         inline const vector[Process*]& getprocesses() #this was std::vector<Process*>&
#         inline const vector[double] & getstate() #this was std::vector<double> &
#
#
#
#         inline double get_last_Timestep()
#         inline unsigned  int get_id_more_evolved_star()
#         inline Star *get_more_evolved_star()
#
#
#         double Radx(size_t starID)
#
#
#
#         inline double get_svpar_num(string name)
#         inline string get_svpar_str(string name)
#         inline bool get_svpar_bool(string name)
#         inline unsigned long get_rseed()
#
#
#
#
#         void evolve() #this is a virtual function!
#
#
#
#
#         inline bool is_process_ongoing(const size_t &id)
#         inline bool processes_alarm(const size_t &id)
#
#         bool process_alarm_any()#const
#
#
#         inline void reset_all_processes_alarms()
#
#
#         inline void reset_events()
#
#
#
#         inline double get_event_from_processes()
#
#
#         bool isoutputtime()
#
#         inline bool printall()
#         inline bool notprint()
#
#
#         void print()
#
#
#
#         void print_failed(bool include_in_output=false)
#
#
#         inline void print_to_log(string& message)
#
#
#         void init(const vector[string] &params)
#
#
#         inline vector[double]  get_zams()
#
#         inline vector[double]  get_Z()
#
#         inline void set_tf(const double a, const char* file, const int line)
#
#         inline void set_dtout(const double a, const char* file, const int line)
#
#         inline void evolution_step_done()
#
#         inline void evolution_guard(const char *file_input = nullptr, int line_input = -1)
#
#         inline double  get_tf()
#
#         inline double get_dtout()
#
#         inline string get_id_name()
#
#
#         sn_explosion check_accretion_on_compact(size_t donorID, size_t accretorID, double DMaccreted)
#
#         void check_accretion_on_compact()
#
#
#
#         bool check_and_set_broken()
#
#
#
#         void check_and_set_bavera_xspin()
#         void check_if_applied_bavera_xspin()
#         double SetXspinBavera(const double, const double)
#
#
#
#
#
#
#
#
#         #Members:
#         double tf
#         double dtout
#         vector[double] state # this was std::vector<double>
#         vector[double] combinedstate
#         vector[vector[double]] allstates
#
#
#         #Methods
#         void synchronise_dt_star()
#         void check_and_sync_sse()
#         void check_and_sync_bse()
#         void check_nakedHe_or_nakedCO_after_binary_evolution()
#         void check_AngMomSpin_after_binary_evolution()
#         void limit_and_correct_mass_transfer_for_donor_from_binary(Star *donor, Star *accretor,
#                                                                size_t mass_limiting_property_id)
#         bool check_and_set_QHE(Star *accretor)
#         void update_derived_properties_star(Star *s)
#         inline void reset_evolution_flags()
#
#
#
#
#
#         SevnLogging svlog
#
#
#
#
#        #MEMBERS
#         vector[Process*] process  # List with all the pointers to the processes initialised in static_main.h
#         vector[BinaryProperty*] property  # List with all the pointers to the binary properties initialised in static_main.h
#         Star *star[2] #Star *star[2]={nullptr, nullptr}  # Pointers to the stars in the binary system, initiliased to nullptr
#         IO *io     #Pointer to the IO object
#         size_t ID  #ID of the binary (it depends on the position of this system in the list of binary
#         vector[string] init_params; #vector of string loaded from the list of binary
#         string name   #Random name of the binary*/
#         unsigned long rseed  #Random seed*/
#
#
#         #METHODS
#         bse_evolution evolve_binary()
#
#         inline void resynch(const double &dt)
#
#
#
#         #Method to clean the heap from all the heap allocated members of this class
#
#         void default_destructor()
#
#
#         # Call the constructor of the two stars with parameters params_star1 and params_star2.
#         # The parameters are Mass, Z, Spin, sn_type, t initial, t final, dt print output.
#         # param params_star1  Mass, Z, Spin, sn_type, t initial, t final, dt print output of the first star.
#         # param params_star2 Mass, Z, Spin, sn_type, t initial, t final, dt print output of the second star
#         #note The random seeds of the stars are set to the same random seed of the binary.
#
#         void call_stars_constructor(vector[string] &params_star1, vector[string] &params_star2)
#
#         # Transform the parameter in input it the stardard form needed from the Star constructor and then call the stars constructor
#         # NB: This is the version that I like more, but it is different with respect the
#         # old SEVN V1 formalism (implemented in init_star_legacy)
#         # The constructor is called in the standard way from a init param vector with:
#         # Mass, Z, Spin, sn_type, t initial, t final, dt print output.
#         # @param params A vector of string with the following orderd parameters:
#         # Mass1, Z1, Spin1, sn_type1,  t_1 initial, Mass2, Z2, Spin2, sn_type2,  t_2 initial,  bin_separation, bin_eccentricity, t_final, dt_out
#
#         void init_stars(const vector[string] &params)
#
#
#         # Transform the parameter in input in the standard format needed from the Star constructor and then call the stars constructor.
#         # The input format is in the old SEVN1 style.
#         # The constructor is called in the standard way from a init param vector with:
#         # Mass, Z, Spin, sn_type, t initial, t final, dt print output.
#         # @param params A vector of string with the following orderd parameters:
#         # Mass1, Mass2, Z1, Z2, Spin1, Spin2, bin_separation, bin_eccentricity, t_final, t_ini, tstep,  sn_type1, sn_type2, dt_out
#         # NB: tstep not used at the moment
#
#         void init_stars_legacy(const vector[string] &params)
#
#
#         # Initialise the Semimajor checking the value
#         # @param a_ini Initial value of the Semimajor axis, it should be larger than 0 or the functions throw a critical error
#
#         inline void set_initial_semimajor(double a_ini)
#
#
#         # Initialise the Semimajor checking the value
#         # param a_ini string with the initial semimajor axis, if the string cannot be transformed to a number the function throw an io error.
#         # a_ini has to be larger than 0 or the functions throw a critical error
#         #
#         inline void set_initial_semimajor(string a_ini)
#
#
#         # Initialise the Eccentricity checking the value
#         # param ecc_ini  Initial value of the eccentricity, it should be lower than 1 and no lower than 0
#
#         inline void set_initial_eccentricity(double ecc_ini)
#
#
#         # Initialise the Eccentricity checking the value
#         # param ecc_ini string with the initial eccentricity, if the string cannot be transformed to a number the function throw an io error.
#         # The initial value of the eccentricity has to  be lower than 1 and no lower than 0
#
#         inline void set_initial_eccentricity(string ecc_ini)
#
#
#         # Initialise the binary parameters.
#         # param params  A vector of string with the following ordered parameters:
#         #          if binput_mode is legacy: Mass1, Mass2, Z1, Z2, Spin1, Spin2, bin_separation, bin_eccentricity, t_final, t_ini, tstep  sn_type1, sn_type2, dt_out
#         #          if binput_mode is new: Mass1, Z1, Spin1, sn_type1,  t_1 initial, Mass2, Z2, Spin2, sn_type2,  t_2 initial,  bin_separation, bin_eccentricity, t_final, dt_out
#
#         inline void init_binary_properties(const vector[string] &params)
#
#
#
#         # In this function we set the parameters that are already set in each star when we call init_stars or init_stars_legacy.
#         # These parameters are: break_at_broken, break_at_remnant, print_all_steps and print_per_phase, tf, dtout.
#         # The function just check that  the two stars store the same value for the parameters to set. It this is not true it throws a critical error.
#         # note this function should be called after the initialisation of the stars (init_stars or init_stars_legacy).
#
#         void  init_other_params()
#
#
#         # Set time when the tf in input is equal to broken
#         # param tf
#
#         void set_break_at_broken(string &tf)
#
#         inline void set_rseed(const unsigned long a, const char* file, const int line)
#
#
#         # Check if params in input has the expected number of parameters as defined in INPUTMAPBIN and INPUTMAPBIN_PARAM (lookup_and_phases.cpp)
#         # param params params to pass to the init function.
#
#         inline void check_init_param(const vector[string] &params)
# Out:
# Overwriting Binstar_h.pxd

# %%
# %%writefile Binstar.pyx
# # cython: no_override=True
#
# # distutils: language = c++
#
#
# from Binstar_h cimport Binstar
#
# cdef class PBinstar:
#
#     cdef Binstar* C_inst   # Hold a heap-allocated C++ instance which we're wrapping
#
#
#
#     def __init__(self):
#         self.C_inst = new Binstar()
#
#
#     def __dealloc__(self):
#         if self.C_inst != NULL:
#             del self.C_inst
# Out:
# Overwriting Binstar.pyx

# %%
# %%writefile setup.py
from distutils.core import setup, Extension
from Cython.Build import cythonize
import glob

path = "/Users/melikakeshavarz/Desktop/sevndevel"

src_files=glob.glob(path +"/src/*.cpp",recursive=True)+\
          glob.glob(path +"/src/binstar/*.cpp",recursive=True)+ \
          glob.glob(path +"/src/binstar/procs/*.cpp",recursive=True)+ \
          glob.glob(path +"/src/general/*.cpp",recursive=True)+\
          glob.glob(path +"/src/general/utils/*.cpp",recursive=True)+\
          glob.glob(path +"/src/star/*.cpp",recursive=True)+\
          glob.glob(path +"/src/star/lambdas/*.cpp",recursive=True)+\
          glob.glob(path +"/src/star/procs/*.cpp",recursive=True)+\
          glob.glob(path +"/src/star/procs/*/*.cpp",recursive=True)+\
          glob.glob(path +"/src/star/procs/*/*.cpp")


ext= Extension("Bin",sources=["Binstar.pyx",]+src_files,
               language="c++",
               extra_compile_args=["-std=c++11"],
               extra_link_args=["-std=c++11"],
               include_dirs = [path +'/include',path+'/include/star',path +'/include/star/lambdas',
                               path +'/include/star/procs/kicks',path +'/include/star/procs/neutrinomassloss',path +'/include/star/procs/pairinstability',
                               path + '/include/star/procs/supernova',
                               path +'/include/general/utils',path +'/include/general/',path +'/include/binstar/procs',
                               path +'/include/star/lambdas',path +'/include/star/procs',path +'/include/binstar'])



setup(name="Bin",ext_modules=cythonize(ext,compiler_directives={'language_level' : "3"}))
# Out:
# Overwriting setup.py

# %%
import os

os.environ["CC"] = "gcc-12"
os.environ["CXX"] = "g++-12"

# %%
# !python3 setup.py build_ext --inplace
# Out:
# Binstar.cpp: In function 'void __pyx_pf_3Bin_8PBinstar_2__dealloc__(__pyx_obj_3Bin_PBinstar*)':
# Binstar.cpp:1553:5: warning: deleting object of polymorphic class type 'Binstar' which has non-virtual destructor might cause undefined behavior [-Wdelete-non-virtual-dtor]
#  1553 |     delete __pyx_v_self->C_inst;
#       |     ^~~~~~~~~~~~~~~~~~~~~~~~~~~
# ld: warning: dylib (/opt/homebrew/Cellar/gcc/12.2.0/lib/gcc/current/libstdc++.dylib) was built for newer macOS version (13.0) than being linked (11.1)
# duplicate symbol '__ZTV5Hobbs' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTT5Hobbs' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTS5Hobbs' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTI5Hobbs' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTv0_n48_N5Hobbs6_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZN5Hobbs6_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZN9HobbsPure6_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZN5Hobbs28estimate_fallback_correctionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTV9HobbsPure' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTS9HobbsPure' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTI9HobbsPure' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/hobbs.o
# duplicate symbol '__ZTV5Kicks' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/kicks.o
# duplicate symbol '__ZTS5Kicks' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/kicks.o
# duplicate symbol '__ZTI5Kicks' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/kicks.o
# duplicate symbol '__ZN5Kicks5applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/kicks.o
# duplicate symbol '__ZN5Kicks23check_and_correct_vkickEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/kicks.o
# duplicate symbol '__ZN5Kicks8InstanceERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/kicks.o
# duplicate symbol '__ZTC9EC15CC2650_5Hobbs' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTC4CC150_5Hobbs' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTv0_n48_N9EC15CC2656_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZN9EC15CC2656_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTv0_n48_N4CC156_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZN4CC156_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZN6ECUS306_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTV9EC15CC265' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTT9EC15CC265' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTS9EC15CC265' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTI9EC15CC265' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTV4CC15' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTT4CC15' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTS4CC15' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTI4CC15' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTV6ECUS30' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTS6ECUS30' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZTI6ECUS30' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/specialkicks.o
# duplicate symbol '__ZN7Unified6_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/unified.o
# duplicate symbol '__ZTV7Unified' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/unified.o
# duplicate symbol '__ZTS7Unified' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/unified.o
# duplicate symbol '__ZTI7Unified' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/unified.o
# duplicate symbol '__ZTV5Zeros' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/zeros.o
# duplicate symbol '__ZTS5Zeros' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/zeros.o
# duplicate symbol '__ZTI5Zeros' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/zeros.o
# duplicate symbol '__ZN5Zeros6_applyEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/kicks/zeros.o
# duplicate symbol '__ZN11NMLDisabledC2Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/neutrinomassloss.o
# duplicate symbol '__ZN11NMLDisabledC1Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/neutrinomassloss.o
# duplicate symbol '__ZN16NeutrinoMassLoss8RegisterEPS_' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/neutrinomassloss.o
# duplicate symbol '__ZN16NeutrinoMassLoss8InstanceERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/neutrinomassloss.o
# duplicate symbol '__ZNK13NMLLattimer895applyEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/nmllattimer89.o
# duplicate symbol '__ZN13NMLLattimer89C2Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/nmllattimer89.o
# duplicate symbol '__ZN13NMLLattimer89C1Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/nmllattimer89.o
# duplicate symbol '__ZTV13NMLLattimer89' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/nmllattimer89.o
# duplicate symbol '__ZTS13NMLLattimer89' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/nmllattimer89.o
# duplicate symbol '__ZTI13NMLLattimer89' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/neutrinomassloss/nmllattimer89.o
# duplicate symbol '__ZNK10PIFarmer1913apply_afterSNEP4Stard' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/farmer19.o
# duplicate symbol '__ZN10PIFarmer19C2Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/farmer19.o
# duplicate symbol '__ZN10PIFarmer19C1Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/farmer19.o
# duplicate symbol '__ZTV10PIFarmer19' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/farmer19.o
# duplicate symbol '__ZTS10PIFarmer19' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/farmer19.o
# duplicate symbol '__ZTI10PIFarmer19' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/farmer19.o
# duplicate symbol '__ZTV15PairInstability' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZTS15PairInstability' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZTI15PairInstability' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZNK15PairInstability14apply_beforeSNEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZNK15PairInstability13apply_afterSNEP4Stard' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZN10PIDisabledC2Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZN10PIDisabledC1Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZN15PairInstability8RegisterEPS_' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZN15PairInstability8InstanceERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pairinstability.o
# duplicate symbol '__ZNK16PIIorio22Limited21ppisn_mass_limitationEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZNK9PIIorio2214apply_beforeSNEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZNK9PIIorio2213apply_afterSNEP4Stard' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZTV16PIIorio22Limited' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZTS16PIIorio22Limited' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZTI16PIIorio22Limited' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZN16PIIorio22LimitedC2Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZN9PIIorio22C2Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZN16PIIorio22LimitedC1Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZN9PIIorio22C1Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZTV9PIIorio22' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZTS9PIIorio22' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZTI9PIIorio22' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/piiorio22.o
# duplicate symbol '__ZNK11PIMapelli2013apply_afterSNEP4Stard' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pimapelli20.o
# duplicate symbol '__ZN11PIMapelli20C2Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pimapelli20.o
# duplicate symbol '__ZN11PIMapelli20C1Eb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pimapelli20.o
# duplicate symbol '__ZN11PIMapelli2015pisn_correctionEdP4StarRN6Lookup15SNExplosionTypeE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pimapelli20.o
# duplicate symbol '__ZTV11PIMapelli20' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pimapelli20.o
# duplicate symbol '__ZTS11PIMapelli20' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pimapelli20.o
# duplicate symbol '__ZTI11PIMapelli20' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/pairinstability/pimapelli20.o
# duplicate symbol '__ZTV11DeathMatrix' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTT11DeathMatrix' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTS11DeathMatrix' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTI11DeathMatrix' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTv0_n56_N11DeathMatrix11CCexplosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZN11DeathMatrix11CCexplosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTv0_n40_N11DeathMatrix9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZN11DeathMatrix9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZN11DeathMatrix10load_tableEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTv0_n64_N11DeathMatrix4ECSNEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZN11DeathMatrix4ECSNEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZN11DeathMatrixC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZN11DeathMatrixC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTC11DeathMatrix8_19NeutrinoMassLossOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTC11DeathMatrix0_7PisnOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZN11DeathMatrix12death_matrixE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/deathmatrix.o
# duplicate symbol '__ZTv0_n40_N7delayed9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZN7delayed9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZN7delayedC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZN13delayed_gauNSC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZN7delayedC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZN13delayed_gauNSC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZTV7delayed' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZTT7delayed' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZTS7delayed' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZTI7delayed' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZTC7delayed0_6PisnON' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/delayed.o
# duplicate symbol '__ZTV11compactness' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZTT11compactness' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZTS11compactness' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZTI11compactness' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZTv0_n40_N11compactness9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZN11compactness9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZN11compactness10load_tableEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZN11compactnessC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZN11compactnessC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZNK11compactness15csi25_mapelli20EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZN11compactness20triggering_explosionEd' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZN11compactness15csi25_mapelli20Ed' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZTC11compactness0_6PisnON' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZN11compactness30csi25_vs_explosion_probabilityE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/compactness.o
# duplicate symbol '__ZTv0_n40_N14directcollapse9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZN14directcollapse9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZN14directcollapseC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZN14directcollapseC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZTV14directcollapse' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZTT14directcollapse' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZTS14directcollapse' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZTI14directcollapse' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZTC14directcollapse8_19NeutrinoMassLossOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZTC14directcollapse0_7PisnOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/directcollapse.o
# duplicate symbol '__ZTv0_n40_N5rapid9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZN5rapid9explosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZN5rapidC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZN11rapid_gauNSC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZN5rapidC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZN11rapid_gauNSC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZTV5rapid' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZTT5rapid' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZTS5rapid' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZTI5rapid' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZTC5rapid0_6PisnON' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/rapid.o
# duplicate symbol '__ZN9supernovaD2Ev' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernovaD1Ev' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernovaD0Ev' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTV9NSfromGau' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTT9NSfromGau' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTS9NSfromGau' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTI9NSfromGau' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova13explosion_SNIEP4StarP7Binstar' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZNK9supernova18neutrino_mass_lossEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTv0_n104_N6PisnON4pisnEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN6PisnON4pisnEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTv0_n104_N7PisnOFF4pisnEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN7PisnOFF4pisnEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova32Mass_corrections_after_explosionEdP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova14set_staremnantEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9NSfromGau11get_NS_massEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTv0_n120_N6PisnON16set_preSN_MassesEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN6PisnON16set_preSN_MassesEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTv0_n120_N7PisnOFF16set_preSN_MassesEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN7PisnOFF16set_preSN_MassesEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova18remnant_propertiesEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova11WDformationEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTv0_n56_N9NSfromGau11CCexplosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9NSfromGau11CCexplosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova11CCexplosionEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova4mainEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTv0_n64_N9NSfromGau4ECSNEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9NSfromGau4ECSNEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova4ECSNEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova13explosion_SNIEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova8InstanceERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEEP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernovaC2EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernovaC1EP4Star' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZNK9supernova14get_preSN_MassEm' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova23set_Average_for_UnifiedEP4Stardd' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova17_set_preSN_MassesEP4Starb' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTV9supernova' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTS9supernova' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTI9supernova' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTV6PisnON' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTT6PisnON' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTS6PisnON' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTI6PisnON' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTV7PisnOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTT7PisnOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTS7PisnOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZTI7PisnOFF' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova18initialise_remnantEP4StardN6Lookup8RemnantsE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# duplicate symbol '__ZN9supernova32set_remnant_type_after_explosionEP4StardN6Lookup15SNExplosionTypeE' in:
#     build/temp.macosx-11.1-arm64-cpython-310/Users/melikakeshavarz/Desktop/sevndevel/src/star/procs/supernova/supernova.o
# ld: 199 duplicate symbols for architecture arm64
# collect2: error: ld returned 1 exit status
# error: command '/opt/homebrew/bin/g++-12' failed with exit code 1
